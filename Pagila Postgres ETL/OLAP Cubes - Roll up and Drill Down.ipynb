# %%
import psycopg2
# %load_ext sql

# %% [markdown]
# ### Connect to the local database

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'postgres'
DB_PASSWORD = 'password'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://postgres:password@127.0.0.1:5432/pagila

# %%
# %sql $conn_string

# %% [markdown]
# ### ERD for the Star Schema

# %% [markdown]
# ![Dimensional Model](Dimension-Model-Schema.jpg)

# %% [markdown]
# ### Roll-up

# %% [markdown]
# - Stepping up the level of aggregation to a large grouping
# - e.g.city is summed as country

# %% [markdown]
# **A query that calculates revenue (sales_amount) by day, rating, and country. Sort the data by revenue in descending order, and limit the data to the top 20 results.**

# %%
# %%time
# %%sql
SELECT t.day, m.rating, s.country, sum(f.sales_amount) as revenue
FROM factsales f 
JOIN dimdate t ON (f.date_key = t.date_key)
JOIN dimmovie m ON (f.movie_key = m.movie_key)
JOIN dimstore s ON (f.store_key = s.store_key)
GROUP BY t.day, m.rating, s.country
ORDER BY  revenue desc
LIMIT 20
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 20 rows affected.
# Wall time: 36.9 ms
# [(30, 'PG-13', 'Canada', Decimal('784.21')),
#  (30, 'G', 'Canada', Decimal('730.48')),
#  (30, 'R', 'Canada', Decimal('683.46')),
#  (30, 'NC-17', 'Australia', Decimal('667.49')),
#  (30, 'NC-17', 'Canada', Decimal('646.51')),
#  (30, 'PG-13', 'Australia', Decimal('635.48')),
#  (30, 'PG', 'Australia', Decimal('593.57')),
#  (30, 'G', 'Australia', Decimal('587.58')),
#  (20, 'PG-13', 'Canada', Decimal('538.93')),
#  (30, 'PG', 'Canada', Decimal('521.78')),
#  (21, 'PG-13', 'Canada', Decimal('499.92')),
#  (30, 'R', 'Australia', Decimal('495.74')),
#  (17, 'PG-13', 'Australia', Decimal('488.83')),
#  (18, 'R', 'Australia', Decimal('472.95')),
#  (18, 'PG-13', 'Canada', Decimal('466.92')),
#  (19, 'PG-13', 'Canada', Decimal('465.87')),
#  (19, 'NC-17', 'Australia', Decimal('456.98')),
#  (28, 'PG-13', 'Canada', Decimal('455.97')),
#  (21, 'NC-17', 'Canada', Decimal('451.95')),
#  (18, 'NC-17', 'Canada', Decimal('447.01'))]

# %% [markdown]
# ### Drill-down

# %% [markdown]
# - Breaking up one of the dimensions to a lower level.
# - e.g.city is broken up into districts

# %% [markdown]
# **A query that calculates revenue (sales_amount) by day, rating, and district. Sort the data by revenue in descending order**

# %%
# %%time
# %%sql
SELECT t.day, m.rating, s.district, sum(f.sales_amount) as revenue
FROM factsales f 
JOIN dimdate t ON (f.date_key = t.date_key)
JOIN dimmovie m ON (f.movie_key = m.movie_key)
JOIN dimstore s ON (f.store_key = s.store_key)
GROUP BY t.day, m.rating,  s.district
ORDER BY  revenue desc
LIMIT 20
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 20 rows affected.
# Wall time: 32.9 ms
# [(30, 'PG-13', 'Alberta', Decimal('784.21')),
#  (30, 'G', 'Alberta', Decimal('730.48')),
#  (30, 'R', 'Alberta', Decimal('683.46')),
#  (30, 'NC-17', 'QLD', Decimal('667.49')),
#  (30, 'NC-17', 'Alberta', Decimal('646.51')),
#  (30, 'PG-13', 'QLD', Decimal('635.48')),
#  (30, 'PG', 'QLD', Decimal('593.57')),
#  (30, 'G', 'QLD', Decimal('587.58')),
#  (20, 'PG-13', 'Alberta', Decimal('538.93')),
#  (30, 'PG', 'Alberta', Decimal('521.78')),
#  (21, 'PG-13', 'Alberta', Decimal('499.92')),
#  (30, 'R', 'QLD', Decimal('495.74')),
#  (17, 'PG-13', 'QLD', Decimal('488.83')),
#  (18, 'R', 'QLD', Decimal('472.95')),
#  (18, 'PG-13', 'Alberta', Decimal('466.92')),
#  (19, 'PG-13', 'Alberta', Decimal('465.87')),
#  (19, 'NC-17', 'QLD', Decimal('456.98')),
#  (28, 'PG-13', 'Alberta', Decimal('455.97')),
#  (21, 'NC-17', 'Alberta', Decimal('451.95')),
#  (18, 'NC-17', 'Alberta', Decimal('447.01'))]
